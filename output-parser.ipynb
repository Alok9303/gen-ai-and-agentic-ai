# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.exceptions import OutputParserException

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model = "llama-3.3-70b-versatile")

# %%
prompt = '''
From the below news article extract the revenue and eps in the json format.
Also keep the units such as million or billion in them.

Only json file. No preamble.

Article
======
{article}
'''

pt = PromptTemplate.from_template(prompt)

# %%
chain = pt | llm

# %%
online_article = '''Here’s how Apple did versus LSEG consensus estimates for the quarter ending Sept. 27: 

EPS: $1.85 vs. $1.77 estimated  
Revenue: $102.47 billion vs. $102.24 billion estimated  
Here’s how Apple’s main business lines did versus consensus estimates:  

iPhone revenue: $49.03 billion vs. $50.19 billion estimated  
Mac revenue: $8.73 billion vs. $8.59 billion estimated  
iPad revenue: $6.95 billion vs. $6.98 billion estimated  
Other Products revenue: $9.01 billion vs. $8.49 billion estimated  
Services revenue: $28.75 billion vs. $28.17 billion estimated 

'''

response = chain.invoke({'article':online_article})
json_string = response.content

# %%
parser = JsonOutputParser()
json_file = parser.parse(json_string)

# %%
type(json_file)
# Out:
# dict

# %%
json_file.items()
# Out:
# dict_items([('EPS', '$1.85'), ('Revenue', '$102.47 billion'), ('iPhone Revenue', '$49.03 billion'), ('Mac Revenue', '$8.73 billion'), ('iPad Revenue', '$6.95 billion'), ('Other Products Revenue', '$9.01 billion'), ('Services Revenue', '$28.75 billion')])
