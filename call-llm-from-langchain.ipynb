# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model='llama3.2:1b', temperature=1.6, num_predict=20)
llm.invoke("The first person to go to moon was")
# Out:
# AIMessage(content='Neil Armstrong was the first person to walk on the Moon. He stepped out of the lunar module Eagle', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-11-24T14:50:30.4483437Z', 'done': True, 'done_reason': 'length', 'total_duration': 3723521000, 'load_duration': 3459306900, 'prompt_eval_count': 33, 'prompt_eval_duration': 27080700, 'eval_count': 20, 'eval_duration': 166492000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--40913107-0e17-432b-afca-5ba25c7cde4b-0', usage_metadata={'input_tokens': 33, 'output_tokens': 20, 'total_tokens': 53})

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm2 = ChatGroq(model = "llama-3.1-8b-instant",temperature=1.2, max_tokens=70)
llm2.invoke("The first person to climb Mount Everest was")
# Out:
# AIMessage(content='Tenzing Norgay (Nepali) and Sir Edmund Hillary successfully reached the summit of Mount Everest on May 29, 1953.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 43, 'total_tokens': 75, 'completion_time': 0.040744667, 'completion_tokens_details': None, 'prompt_time': 0.002286511, 'prompt_tokens_details': None, 'queue_time': 0.055103879, 'total_time': 0.043031178}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--cd5112e8-68e7-4c34-a213-c428b1b01ed0-0', usage_metadata={'input_tokens': 43, 'output_tokens': 32, 'total_tokens': 75})
